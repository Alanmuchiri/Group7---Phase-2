# %% [markdown]
# # ***FILM PERFOMANCE ANALYSIS***
#
# ---

# %% [markdown]
# ![a68b17be-6311-4d99-a120-68d66b13162c.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## **Overview**
#
# ---

# %% [markdown]
# This project aims to use exploratory data analysis(EDA) among other data anlysis tools to generate valuable market foresight in the film industry for a business stakeholder.

# %% [markdown]
# ## ***Business Problem***
#
# ---
#
# The company sees an opportunity in venturing into original video creation.They have decided to create a new movie studio,the current market is dominated by established studios with strong franchises, massive marketing budgets, and global distribution power.
#
# The aim is to determinine what types of films a new studio can produce that align with current audience demand, minimize financial risk, and still allow the company to compete for box-office revenue.

# %% [markdown]
# ## ***Data Understanding And Preparation***
#
# ---
# The dataset is derived from publicly available movie databases including Box Office Mojo, IMDb, Rotten Tomatoes, and The Movie Database.These sources are widely recognized platforms that aggregate data from industry reports, critics, and user contributions, making the dataset suitable for analyzing relationships between movie characteristics, reception, and commercial success.

# %%
# import the relevant libraries

import pandas as pd
from scipy.stats import skew, kurtosis
import numpy as np
import _sqlite3
import seaborn as sns
import matplotlib.pyplot as plt
import ast
from scipy.stats import norm

# %% [markdown]
# We used three datasets to do our analysis and come up with actionable insights.

# %% [markdown]
# #1.bom.movies.csv
#
# * This is a csv file that contains movies, studio, gross domestically and foreign and year of release.

# %%
# Loading our dataset

df = pd.read_csv('Data/bom.movie_gross.csv')
df.head(10) # Quick look at our data
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
# 5                   The Twilight Saga: Eclipse   Sum.     300500000.0
# 6                                   Iron Man 2   Par.     312400000.0
# 7                                      Tangled     BV     200800000.0
# 8                                Despicable Me   Uni.     251500000.0
# 9                     How to Train Your Dragon   P/DW     217600000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010
# 5     398000000  2010
# 6     311500000  2010
# 7     391000000  2010
# 8     291600000  2010
# 9     277300000  2010

# %%
# How big is our data?
df.shape
# Out:
# (3387, 5)

# %%
# what type of columns are we working with?
df.columns
# Out:
# Index(['title', 'studio', 'domestic_gross', 'foreign_gross', 'year'], dtype='object')

# %%
# General summary of our data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
# Statistical summary for the numeric columns.
df.describe()
# Out:
#        domestic_gross         year
# count    3.359000e+03  3387.000000
# mean     2.874585e+07  2013.958075
# std      6.698250e+07     2.478141
# min      1.000000e+02  2010.000000
# 25%      1.200000e+05  2012.000000
# 50%      1.400000e+06  2014.000000
# 75%      2.790000e+07  2016.000000
# max      9.367000e+08  2018.000000

# %% [markdown]
# *   Mean is much higher than the median indicating a right skewed distribution caused by a few movies earning higher revenue.
# *   Revenues vary widely, from very low grossing movies to extremely sucessfull.
#
# *  Most movies in the dataset were released around 2013-2014.
#
# * More movies earn more internationally than domestically.
#
# * Foreign earnings vary even more widely than domestic earnings.

# %%
# Check for missing values.
df.isnull().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %%
# Dropping the missing values
df_cleaned = df.dropna(subset=["domestic_gross", "foreign_gross"])

# %%
# Converting the foreign_gross column to a numeric column
for col in ["domestic_gross", "foreign_gross"]:
    df_cleaned[col] = pd.to_numeric(
        df_cleaned[col].astype(str).str.replace(",", ""),
        errors="coerce"
    )
# Out:
# C:\Users\compweb\AppData\Local\Temp\ipykernel_10148\734072323.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned[col] = pd.to_numeric(
# C:\Users\compweb\AppData\Local\Temp\ipykernel_10148\734072323.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned[col] = pd.to_numeric(

# %%
# Feature Engineering
df_cleaned["net_gross"] = (
    df_cleaned["domestic_gross"] + df_cleaned["foreign_gross"]
)
# Out:
# C:\Users\compweb\AppData\Local\Temp\ipykernel_10148\3159865547.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned["net_gross"] = (

# %% [markdown]
# * Looking at only domestic or only foreign gross gives a partial and sometimes misleading picture.
#
# * Net gross gives you a movie’s total box-office performance, not just how it did in one market.

# %%
# Do we have any duplicated values?
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# *   There are no duplicated values in our dataset.

# %%
# Resetting the dataframe index
df_cleaned = df.reset_index(drop=True)

# %%
# Verifying changes
df_cleaned.shape
df_cleaned.info()
df_cleaned.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %% [markdown]
# #2.The tmdb.csv
#
# This file  contains info on various aspects of different movies like title, release date , ratings e.t.c

# %%
tm_df = pd.read_csv('Data/tmdb.movies.csv',index_col=0)
tm_df.head(10)
# Out:
#                   genre_ids     id original_language  \
# 0           [12, 14, 10751]  12444                en
# 1       [14, 12, 16, 10751]  10191                en
# 2             [12, 28, 878]  10138                en
# 3           [16, 35, 10751]    862                en
# 4             [28, 878, 12]  27205                en
# 5           [12, 14, 10751]  32657                en
# 6         [28, 12, 14, 878]  19995                en
# 7           [16, 10751, 35]  10193                en
# 8           [16, 10751, 35]  20352                en
# 9  [16, 28, 35, 10751, 878]  38055                en
#
#                                       original_title  popularity release_date  \
# 0       Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                           How to Train Your Dragon      28.734   2010-03-26
# 2                                         Iron Man 2      28.515   2010-05-07
# 3                                          Toy Story      28.005   1995-11-22
# 4                                          Inception      27.920   2010-07-16
# 5  Percy Jackson & the Olympians: The Lightning T...      26.691   2010-02-11
# 6                                             Avatar      26.526   2009-12-18
# 7                                        Toy Story 3      24.445   2010-06-17
# 8                                      Despicable Me      23.673   2010-07-09
# 9                                           Megamind      22.855   2010-11-04
#
#                                                title  vote_average  vote_count
# 0       Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                           How to Train Your Dragon           7.7        7610
# 2                                         Iron Man 2           6.8       12368
# 3                                          Toy Story           7.9       10174
# 4                                          Inception           8.3       22186
# 5  Percy Jackson & the Olympians: The Lightning T...           6.1        4229
# 6                                             Avatar           7.4       18676
# 7                                        Toy Story 3           7.7        8340
# 8                                      Despicable Me           7.2       10057
# 9                                           Megamind           6.8        3635

# %%
# How big is our data?
tm_df.shape
# Out:
# (26517, 9)

# %% [markdown]
# *   Our dataset has 26,517 columns and 10 rows.

# %%
# General summary of our data
tm_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26517 entries, 0 to 26516
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   genre_ids          26517 non-null  object
#  1   id                 26517 non-null  int64
#  2   original_language  26517 non-null  object
#  3   original_title     26517 non-null  object
#  4   popularity         26517 non-null  float64
#  5   release_date       26517 non-null  object
#  6   title              26517 non-null  object
#  7   vote_average       26517 non-null  float64
#  8   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# *  Our dataset has no missing values.
# *  The release date column is of type object and should be converted to datetime.

# %% [markdown]
# # ***Data Cleaning***
#
# ---

# %%
# What is the genre_id column made of

tm_df['genre_ids'].head()
# Out:
# 0        [12, 14, 10751]
# 1    [14, 12, 16, 10751]
# 2          [12, 28, 878]
# 3        [16, 35, 10751]
# 4          [28, 878, 12]
# Name: genre_ids, dtype: object

# %% [markdown]
# *   Genre Id which is an important column is not readable and it would be better if we can map the genre_ids to their respective genres.

# %%
# strings to integers

tm_df['genre_ids'] = tm_df['genre_ids'].apply(
    lambda x: list(map(int, ast.literal_eval(x)))
)

# %% [markdown]
# *  genre ids are stored inside python strings we have to convert them to integers for our mapping to work.

# %%
# mapping our genres
genre_map = {
    28: "Action",
    12: "Adventure",
    16: "Animation",
    35: "Comedy",
    18: "Drama",          # TMDB Genre mapping
    14: "Fantasy",
    27: "Horror",
    53: "Thriller",
    80: "Crime",
    878: "Science Fiction",
    10749: "Romance",
    10751: "Family"
}

# %%
tm_df['genres'] = tm_df['genre_ids'].apply(
    lambda ids: [genre_map.get(i, 'Other') for i in ids]
)

# %%
tm_df['genres'].head(10)
# Out:
# 0                         [Adventure, Fantasy, Family]
# 1              [Fantasy, Adventure, Animation, Family]
# 2                 [Adventure, Action, Science Fiction]
# 3                          [Animation, Comedy, Family]
# 4                 [Action, Science Fiction, Adventure]
# 5                         [Adventure, Fantasy, Family]
# 6        [Action, Adventure, Fantasy, Science Fiction]
# 7                          [Animation, Family, Comedy]
# 8                          [Animation, Family, Comedy]
# 9    [Animation, Action, Comedy, Family, Science Fi...
# Name: genres, dtype: object

# %% [markdown]
# *  Now we have a more readable column and we can associate movies to their genres.

# %%
tmdf_cleaned = tm_df.explode('genres').copy()

# %% [markdown]
# *   Flattening a nested list column for easier analysis.

# %%
# converting the release date column to type datetime
tm_df["release_date"] = pd.to_datetime(tm_df["release_date"], errors="coerce")

# Extracting Release year from the column.
tm_df["release_year"] = tm_df["release_date"].dt.year

# %%
# Renaming some of the columns

tmdf_cleaned = tm_df.rename(columns={'vote_average':'AVG Rating','vote_count':'Vote Count','genres':'Genre','popularity':'Popularity'})

# %%
# Dropping genre_id column

tmdf_cleaned = tmdf_cleaned.drop(columns=['genre_ids'])

# %% [markdown]
# *   Since we already mapped our genre ids to their genres we no longer need the latter column.

# %%
# Saving the cleaned dataset
tmdf_cleaned.to_csv('tmdb.movies_cleaned.csv',index=False)

# %% [markdown]
# #3. im.db dataset
#
# * This is an sql dataset that contains information about various aspects of the movie production process like actors,directors,writers e.t.c.

# %%
import zipfile
import os
import sqlite3

# Define the path to the zip file and extraction directory
zip_file_path = 'im.db.zip'
extract_dir = 'Data' # Extract to the same Data folder

# Unzip the file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

# Verify extraction (optional)
extracted_db_path = os.path.join(extract_dir, 'im.db')
print(f"Extracted database path: {extracted_db_path}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[137], line 10
#       7 extract_dir = 'Data' # Extract to the same Data folder
#       9 # Unzip the file
# ---> 10 with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
#      11     zip_ref.extractall(extract_dir)
#      13 # Verify extraction (optional)
#
# File c:\Users\compweb\anaconda3\Lib\zipfile\__init__.py:1367, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1365 while True:
#    1366     try:
# -> 1367         self.fp = io.open(file, filemode)
#    1368     except OSError:
#    1369         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'im.db.zip'

# %%
db_path = "Data/im.db" # ← use the extracted path
conn = sqlite3.connect(db_path)

pd.read_sql("""
SELECT name
FROM sqlite_master
WHERE type = 'table';
""", conn)
# Out:
#             name
# 0   movie_basics
# 1      directors
# 2      known_for
# 3     movie_akas
# 4  movie_ratings
# 5        persons
# 6     principals
# 7        writers

# %%
pd.read_sql("""
SELECT *
FROM movie_basics
LIMIT 50;
""",conn
)
# Out:
#      movie_id                                      primary_title  \
# 0   tt0063540                                          Sunghursh
# 1   tt0066787                    One Day Before the Rainy Season
# 2   tt0069049                         The Other Side of the Wind
# 3   tt0069204                                    Sabse Bada Sukh
# 4   tt0100275                           The Wandering Soap Opera
# 5   tt0111414                                        A Thin Life
# 6   tt0112502                                            Bigfoot
# 7   tt0137204                                    Joe Finds Grace
# 8   tt0139613                                         O Silêncio
# 9   tt0144449                              Nema aviona za Zagreb
# 10  tt0146592                                        Pál Adrienn
# 11  tt0154039                               So Much for Justice!
# 12  tt0159369                 Cooper and Hemingway: The True Gen
# 13  tt0162942                       Children of the Green Dragon
# 14  tt0170651                               T.G.M. - osvoboditel
# 15  tt0176694                                 The Tragedy of Man
# 16  tt0187902  How Huang Fei-hong Rescued the Orphan from the...
# 17  tt0192528                                      Heaven & Hell
# 18  tt0230212                                  The Final Journey
# 19  tt0247643                   Los pájaros se van con la muerte
# 20  tt0249516                                         Foodfight!
# 21  tt0250404                                          Godfather
# 22  tt0253093                                       Gangavataran
# 23  tt0255820                                  Return to Babylon
# 24  tt0262218                                  Akakis mogzauroba
# 25  tt0262759                           Seven Jews from My Class
# 26  tt0263814                                           On kadin
# 27  tt0276568                                 To Chase a Million
# 28  tt0277964               Prague: The Restless Heart of Europe
# 29  tt0283440                                  Short Time Heroes
# 30  tt0285252                                     Life's a Beach
# 31  tt0285423                                           Abolição
# 32  tt0293069                                         Dark Blood
# 33  tt0293429                                      Mortal Kombat
# 34  tt0297400                                          Snowblind
# 35  tt0306058                                      Second Coming
# 36  tt0311448                               Lives No Longer Ours
# 37  tt0312305             Quantum Quest: A Cassini Space Odyssey
# 38  tt0315642                                              Wazir
# 39  tt0323808                                    The Wicker Tree
# 40  tt0326592                                      The Overnight
# 41  tt0326965                                        In My Sleep
# 42  tt0328810                                            My Land
# 43  tt0329539                                          Rice Girl
# 44  tt0330811                                Regret Not Speaking
# 45  tt0330987                            Tiden är en dröm, del 2
# 46  tt0331312                                 This Wretched Life
# 47  tt0331314                                    Bunyan and Babe
# 48  tt0337692                                        On the Road
# 49  tt0337882                                        Blind Sided
#
#                                        original_title  start_year  \
# 0                                           Sunghursh        2013
# 1                                     Ashad Ka Ek Din        2019
# 2                          The Other Side of the Wind        2018
# 3                                     Sabse Bada Sukh        2018
# 4                               La Telenovela Errante        2017
# 5                                         A Thin Life        2018
# 6                                             Bigfoot        2017
# 7                                     Joe Finds Grace        2017
# 8                                          O Silêncio        2012
# 9                               Nema aviona za Zagreb        2012
# 10                                        Pál Adrienn        2010
# 11                                     Oda az igazság        2010
# 12                 Cooper and Hemingway: The True Gen        2013
# 13                           A zöld sárkány gyermekei        2010
# 14                               T.G.M. - osvoboditel        2018
# 15                                Az ember tragédiája        2011
# 16  How Huang Fei-hong Rescued the Orphan from the...        2011
# 17                                     Reverse Heaven        2018
# 18                                  The Final Journey        2010
# 19                   Los pájaros se van con la muerte        2011
# 20                                         Foodfight!        2012
# 21                                          Godfather        2012
# 22                                       Gangavataran        2018
# 23                                  Return to Babylon        2013
# 24                                  Akakis mogzauroba        2012
# 25                        Siedmiu Zydów z mojej klasy        2018
# 26                                           On kadin        2019
# 27                                 To Chase a Million        2018
# 28                      Praha - neklidné srdce Evropy        2018
# 29                                     Kurzzeithelden        2015
# 30                                     Life's a Beach        2012
# 31                                           Abolição        2019
# 32                                         Dark Blood        2012
# 33                                      Mortal Kombat        2021
# 34                                          Snowblind        2015
# 35                                      Second Coming        2012
# 36                               Lives No Longer Ours        2011
# 37             Quantum Quest: A Cassini Space Odyssey        2010
# 38                                              Wazir        2016
# 39                                    The Wicker Tree        2011
# 40                                      The Overnight        2010
# 41                                        In My Sleep        2010
# 42                                      Aamaar Bhuvan        2018
# 43                                          Rice Girl        2014
# 44                                Regret Not Speaking        2011
# 45                            Tiden är en dröm, del 2        2014
# 46                                 This Wretched Life        2010
# 47                                    Bunyan and Babe        2017
# 48                                        On the Road        2012
# 49                                        Blind Sided        2010
#
#     runtime_minutes                      genres
# 0             175.0          Action,Crime,Drama
# 1             114.0             Biography,Drama
# 2             122.0                       Drama
# 3               NaN                Comedy,Drama
# 4              80.0        Comedy,Drama,Fantasy
# 5              75.0                      Comedy
# 6               NaN             Horror,Thriller
# 7              83.0  Adventure,Animation,Comedy
# 8               NaN         Documentary,History
# 9              82.0                   Biography
# 10            136.0                       Drama
# 11            100.0                     History
# 12            180.0                 Documentary
# 13             89.0                       Drama
# 14             60.0                 Documentary
# 15            160.0     Animation,Drama,History
# 16              NaN                        None
# 17            104.0                       Drama
# 18            120.0                       Drama
# 19            110.0               Drama,Mystery
# 20             91.0     Action,Animation,Comedy
# 21              NaN                 Crime,Drama
# 22            134.0                        None
# 23             75.0      Biography,Comedy,Drama
# 24             44.0                 Documentary
# 25             40.0                 Documentary
# 26              NaN                       Drama
# 27             97.0                Action,Drama
# 28             59.0         Documentary,History
# 29             45.0                      Sci-Fi
# 30            100.0                      Comedy
# 31              NaN                 Documentary
# 32             86.0                    Thriller
# 33              NaN    Action,Adventure,Fantasy
# 34              NaN                 Crime,Drama
# 35             95.0                        None
# 36             90.0               Drama,Romance
# 37             45.0  Adventure,Animation,Sci-Fi
# 38            103.0          Action,Crime,Drama
# 39             96.0                Drama,Horror
# 40             88.0                        None
# 41            104.0      Drama,Mystery,Thriller
# 42            102.0                Drama,Family
# 43             95.0    Adventure,Comedy,Romance
# 44              NaN                        None
# 45            109.0                        None
# 46             99.0                Comedy,Drama
# 47             84.0  Adventure,Animation,Comedy
# 48            124.0     Adventure,Drama,Romance
# 49              NaN          Comedy,Crime,Drama

# %% [markdown]
# ## ***Data Analysis And Visualization***
#
# ---

# %% [markdown]
# # Uni-variate analysis

# %%
df = pd.read_csv('Data/bom.movie_gross(cleaned).csv')

plt.figure(figsize=(8,5))
sns.boxplot(x=df['foreign_gross'])
plt.title("Box Plot of Foreign Gross Revenue")
plt.xlabel("Foreign Gross Revenue")
plt.show()
plt.savefig('visuals/foreign_gross_boxplot.png')

# %%
cols = ['domestic_gross','foreign_gross','net_gross']

for col in cols:
    print(col)
    print("Skew:", skew(df[col].dropna()))
    print("Kurtosis:", kurtosis(df[col].dropna()))
    print("---")
# Out:
# domestic_gross
# Skew: 3.7091956892429345
# Kurtosis: 20.329185706835336
# ---
# foreign_gross
# Skew: 3.0701974178134774
# Kurtosis: 10.687705061520475
# ---
# net_gross
# Skew: 2.9994078960354407
# Kurtosis: 10.357110399458993
# ---

# %%
# Compute skew and kurtosis

cols = ['domestic_gross', 'foreign_gross', 'net_gross']

# Clean numeric columns (remove $, commas if needed)
for col in cols:
    df[col] = df[col].replace('[\$,]', '', regex=True)
    df[col] = pd.to_numeric(df[col], errors='coerce')

df_clean = df[cols].dropna()

for col in cols:
    data = df_clean[col]

    s = skew(data)
    k = kurtosis(data)

    # Plot histogram + density + normal overlay
    plt.figure(figsize=(8,5))
    sns.histplot(data, bins=50, kde=True, color='skyblue', stat='density')

    # Overlay normal distribution for comparison
    x = np.linspace(data.min(), data.max(), 1000)
    plt.plot(x, norm.pdf(x, data.mean(), data.std()), color='red', linestyle='--', label='Normal dist')

    plt.title(f'{col} Distribution\nSkewness={s:.2f}, Kurtosis={k:.2f}')
    plt.xlabel(col)
    plt.ylabel('Density')
    plt.legend()
    plt.show()
    plt.savefig(f'visuals/{col}_distribution.png')

# %%
 # Frequency Table

bins = [0, 10e6, 50e6, 100e6, 500e6, 1e9]
labels = ['0-10M', '10-50M', '50-100M', '100-500M', '500M+']
df['domestic_bin'] = pd.cut(df['domestic_gross'], bins=bins, labels=labels)
df['domestic_bin'].value_counts().sort_index()
# Out:
# domestic_bin
# 0-10M       893
# 10-50M      549
# 50-100M     283
# 100-500M    275
# 500M+         9
# Name: count, dtype: int64

# %%
# Count the number of movies in each bin
bin_counts = df['domestic_bin'].value_counts().sort_index()

# Plot
plt.figure(figsize=(8,5))
sns.barplot(x=bin_counts.index, y=bin_counts.values, palette='viridis')
plt.title("Number of Movies by Domestic Gross Range")
plt.xlabel("Domestic Gross Range")
plt.ylabel("Number of Movies")
plt.xticks(rotation=45)
plt.show()
plt.savefig('visuals/movies_by_domestic_gross_range.png')
# Out:
# C:\Users\compweb\AppData\Local\Temp\ipykernel_10148\212866324.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=bin_counts.index, y=bin_counts.values, palette='viridis')

# %% [markdown]
# ### BI-VARIATE ANALYSIS & VISUALIZATION

# %%
bom_df = pd.read_csv('Data/bom.movie_gross(cleaned).csv')
tmdb_df = pd.read_csv('Data/tmdb.movies_cleaned.csv')
tm_budget_df  = pd.read_csv('Data/tn.movie_budgets.csv')
#imdb_df = pd.read_sql('SELECT * FROM imdb_movies', con=sqlite3.connect('Data/im.db'))

# %%
bom_df
# Out:
#                                                   title        studio  \
# 0                                           Toy Story 3            BV
# 1                            Alice in Wonderland (2010)            BV
# 2           Harry Potter and the Deathly Hallows Part 1            WB
# 3                                             Inception            WB
# 4                                   Shrek Forever After          P/DW
# ...                                                 ...           ...
# 2004                                    I Still See You           LGF
# 2005                              The Catcher Was a Spy           IFC
# 2006                                         Time Freak    Grindstone
# 2007  Reign of Judges: Title of Liberty - Concept Short  Darin Southa
# 2008            Antonio Lopez 1970: Sex Fashion & Disco            FM
#
#       domestic_gross  foreign_gross  year     net_gross
# 0        415000000.0    652000000.0  2010  1.067000e+09
# 1        334200000.0    691300000.0  2010  1.025500e+09
# 2        296000000.0    664300000.0  2010  9.603000e+08
# 3        292600000.0    535700000.0  2010  8.283000e+08
# 4        238700000.0    513900000.0  2010  7.526000e+08
# ...              ...            ...   ...           ...
# 2004          1400.0      1500000.0  2018  1.501400e+06
# 2005        725000.0       229000.0  2018  9.540000e+05
# 2006         10000.0       256000.0  2018  2.660000e+05
# 2007         93200.0         5200.0  2018  9.840000e+04
# 2008         43200.0        30000.0  2018  7.320000e+04
#
# [2009 rows x 6 columns]

# %%
bom_filtered  =  bom_df[bom_df['domestic_gross'] > 100000000]
bom_filtered
# Out:
#                                             title studio  domestic_gross  \
# 0                                     Toy Story 3     BV     415000000.0
# 1                      Alice in Wonderland (2010)     BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                       Inception     WB     292600000.0
# 4                             Shrek Forever After   P/DW     238700000.0
# ...                                           ...    ...             ...
# 1873                            Crazy Rich Asians     WB     174500000.0
# 1876                                     Creed II    MGM     115700000.0
# 1878                              The Equalizer 2   Sony     102100000.0
# 1880                                     The Mule     WB     103800000.0
# 1886                            A Wrinkle in Time     BV     100500000.0
#
#       foreign_gross  year     net_gross
# 0       652000000.0  2010  1.067000e+09
# 1       691300000.0  2010  1.025500e+09
# 2       664300000.0  2010  9.603000e+08
# 3       535700000.0  2010  8.283000e+08
# 4       513900000.0  2010  7.526000e+08
# ...             ...   ...           ...
# 1873     64000000.0  2018  2.385000e+08
# 1876     98300000.0  2018  2.140000e+08
# 1878     88300000.0  2018  1.904000e+08
# 1880     68700000.0  2018  1.725000e+08
# 1886     32200000.0  2018  1.327000e+08
#
# [284 rows x 6 columns]

# %% [markdown]
# #### Top movies by net gross

# %%
plt.figure(figsize=(10, 6))
top_10 = bom_filtered.sort_values(by='net_gross', ascending=False).head(30)
plt.barh(top_10['title'][::-1], top_10['net_gross'][::-1], color='skyblue')
plt.xlabel('Net Gross (in Millions)')
plt.title('Top 10 Movies by Net Gross')
plt.tight_layout()
plt.savefig('visuals/top_10_movies_net_gross.png')

# %% [markdown]
# #### TOTAL NET GROSS TREND OVER THE YEARS

# %%
plt.figure(figsize=(10, 6))
yearly_gross = bom_df.groupby('year')['net_gross'].sum().sort_index()
plt.plot(yearly_gross.index, yearly_gross.values, marker='o', linestyle='-', color='green')
plt.xlabel('Year')
plt.ylabel('Total Net Gross (in Millions)')
plt.title('Total Net Gross Trend Over Years')
plt.grid(True)
plt.tight_layout()
plt.savefig('visuals/total_net_gross_trend.png')

# %% [markdown]
# #### STUDIO COMPARISON (DOMESTIC AND  FOREIGN GROSS EARNINGS) OVER THe YEARS

# %%
studio_gross = bom_df.groupby('studio')[['domestic_gross', 'foreign_gross', 'net_gross']].sum()
studio_gross = studio_gross.sort_values(by='net_gross', ascending=False).head(30)

ax = studio_gross[['domestic_gross', 'foreign_gross']].plot(
    kind='bar',
    stacked=True, 
    figsize=(14, 7), 
    width=0.8, 
    color=['royalblue', 'orange']
)

plt.xlabel('Studio', fontsize=12)
plt.ylabel('Gross (in Millions)', fontsize=12)
plt.title('Top 30 Studios: Domestic vs Foreign Gross', fontsize=14)
plt.legend(['Domestic Gross', 'Foreign Gross'])
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig('visuals/studio_comparison.png')

# %%
tmdb_df
# Out:
#                  genre_ids      id original_language  \
# 0          [12, 14, 10751]   12444                en
# 1          [12, 14, 10751]   12444                en
# 2          [12, 14, 10751]   12444                en
# 3      [14, 12, 16, 10751]   10191                en
# 4      [14, 12, 16, 10751]   10191                en
# ...                    ...     ...               ...
# 47829      [10751, 12, 28]  366854                en
# 47830      [10751, 12, 28]  366854                en
# 47831      [10751, 12, 28]  366854                en
# 47832             [53, 27]  309885                en
# 47833             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 2      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 3                          How to Train Your Dragon      28.734   2010-03-26
# 4                          How to Train Your Dragon      28.734   2010-03-26
# ...                                             ...         ...          ...
# 47829                                  Trailer Made       0.600   2018-06-22
# 47830                                  Trailer Made       0.600   2018-06-22
# 47831                                  Trailer Made       0.600   2018-06-22
# 47832                                    The Church       0.600   2018-10-05
# 47833                                    The Church       0.600   2018-10-05
#
#                                               title  vote_average  vote_count  \
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 2      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 3                          How to Train Your Dragon           7.7        7610
# 4                          How to Train Your Dragon           7.7        7610
# ...                                             ...           ...         ...
# 47829                                  Trailer Made           0.0           1
# 47830                                  Trailer Made           0.0           1
# 47831                                  Trailer Made           0.0           1
# 47832                                    The Church           0.0           1
# 47833                                    The Church           0.0           1
#
#        release_year     genres
# 0              2010  Adventure
# 1              2010    Fantasy
# 2              2010     Family
# 3              2010    Fantasy
# 4              2010  Adventure
# ...             ...        ...
# 47829          2018     Family
# 47830          2018  Adventure
# 47831          2018     Action
# 47832          2018   Thriller
# 47833          2018     Horror
#
# [47834 rows x 11 columns]

# %%
tmdb_filtered_df = tmdb_df[tmdb_df['vote_average'] >= 5]
tmdb = tmdb_filtered_df
tmdb
# Out:
#                  genre_ids      id original_language  \
# 0          [12, 14, 10751]   12444                en
# 1          [12, 14, 10751]   12444                en
# 2          [12, 14, 10751]   12444                en
# 3      [14, 12, 16, 10751]   10191                en
# 4      [14, 12, 16, 10751]   10191                en
# ...                    ...     ...               ...
# 47748         [36, 99, 18]  458823                en
# 47749         [36, 99, 18]  458823                en
# 47750                 [99]  448912                fr
# 47751                 [99]  406486                en
# 47752                 [18]  397827                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 2      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 3                          How to Train Your Dragon      28.734   2010-03-26
# 4                          How to Train Your Dragon      28.734   2010-03-26
# ...                                             ...         ...          ...
# 47748                       Acorn and the Firestorm       0.600   2018-04-06
# 47749                       Acorn and the Firestorm       0.600   2018-04-06
# 47750                             Maison du bonheur       0.600   2018-08-24
# 47751        Boy Howdy! The Story of CREEM Magazine       0.600   2018-10-01
# 47752                 No Light and No Land Anywhere       0.600   2018-03-16
#
#                                               title  vote_average  vote_count  \
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 2      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 3                          How to Train Your Dragon           7.7        7610
# 4                          How to Train Your Dragon           7.7        7610
# ...                                             ...           ...         ...
# 47748                       Acorn and the Firestorm           5.0           1
# 47749                       Acorn and the Firestorm           5.0           1
# 47750                             Maison du bonheur           5.0           1
# 47751        Boy Howdy! The Story of CREEM Magazine           5.0           1
# 47752                 No Light and No Land Anywhere           5.0           1
#
#        release_year     genres
# 0              2010  Adventure
# 1              2010    Fantasy
# 2              2010     Family
# 3              2010    Fantasy
# 4              2010  Adventure
# ...             ...        ...
# 47748          2018      Other
# 47749          2018      Drama
# 47750          2018      Other
# 47751          2018      Other
# 47752          2018      Drama
#
# [36926 rows x 11 columns]

# %% [markdown]
# #### MOVIE GENRE BY AVERAGE POPULARITY

# %%
plt.figure(figsize=(10, 6))
top_genres = tmdb.groupby('genres')['popularity'].mean().sort_values(ascending=False).head(20)
sns.barplot(x=top_genres.values, y=top_genres.index, palette='viridis')
plt.title('Top Movie Genres by Average Popularity')
plt.xlabel('Average Popularity Score')
plt.ylabel
plt.show()
plt.savefig('visuals/top_genres_popularity.png')
# Out:
# C:\Users\compweb\AppData\Local\Temp\ipykernel_10148\2455497526.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_genres.values, y=top_genres.index, palette='viridis')

# %% [markdown]
# #### MOVIE POPULARITY VS RATINGS

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=tmdb, x='vote_average', y='popularity', 
                size='vote_count', alpha=0.5, sizes=(20, 500))
plt.title('Popularity vs. Rating (Size = Vote Count)')
plt.xlabel('Average Vote (Rating)')
plt.ylabel('Popularity')
plt.show()
plt.savefig('visuals/popularity_vs_rating.png')

# %% [markdown]
# #### YEARLY RELEASE TREND

# %%
plt.figure(figsize=(12, 5))
yearly_counts = tmdb_df['release_year'].value_counts().sort_index()
plt.plot(yearly_counts.index, yearly_counts.values, marker='o', color='red')
plt.title('Number of Movies Released per Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.grid(True, linestyle='--')
plt.show()

# %% [markdown]
# #### DISTRIBUTION OF MOVIE RATINGS

# %%
plt.figure(figsize=(10, 6))
sns.histplot(tmdb_df['vote_average'], bins=20, kde=True, color='teal')
plt.title('Distribution of Movie Ratings')
plt.xlabel('Rating (Vote Average)')
plt.ylabel('Number of Movies')
plt.show()
plt.savefig('visuals/movie_ratings_distribution.png')

# %% [markdown]
# #### Average Rating by Language (Top 10 most frequent languages)

# %%
top_langs = tmdb_df['original_language'].value_counts().head(10).index
filtered_df = tmdb_df[tmdb_df['original_language'].isin(top_langs)]

plt.figure(figsize=(12, 6))
sns.barplot(data=filtered_df, x='original_language', y='vote_average', estimator='mean', palette='magma')
plt.title('Average Rating per Language')
plt.ylim(0, 10) 
plt.show()
plt.savefig('visuals/average_rating_per_language.png')
# Out:
# C:\Users\compweb\AppData\Local\Temp\ipykernel_10148\306759658.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=filtered_df, x='original_language', y='vote_average', estimator='mean', palette='magma')

# %% [markdown]
# #### ENGAGEMENT CORRELATION (POPULATION VS  VOTECOUNT )

# %%
plt.figure(figsize=(10, 6))
sns.regplot(data=tmdb_df, x='vote_count', y='popularity', scatter_kws={'alpha':0.3}, line_kws={'color':'red'})
plt.title('Correlation: Total Votes vs. Current Popularity')
plt.show()
plt.savefig('visuals/total_votes_vs_popularity.png')
